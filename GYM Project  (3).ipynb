# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_1samp

# %%
gym=pd.read_csv("gym_membership.csv")
gym
# Out:
#        id  gender    birthday  Age abonoment_type  visit_per_week  \
# 0       1  Female  1997-04-18   27        Premium               4
# 1       2  Female  1977-09-18   47       Standard               3
# 2       3    Male  1983-03-30   41        Premium               1
# 3       4    Male  1980-04-12   44        Premium               3
# 4       5    Male  1980-09-10   44       Standard               2
# ..    ...     ...         ...  ...            ...             ...
# 995   996  Female  1984-09-22   40       Standard               3
# 996   997  Female  2008-11-19   15       Standard               3
# 997   998    Male  1984-10-05   40       Standard               2
# 998   999    Male  2001-02-22   23       Standard               4
# 999  1000  Female  2006-05-07   18        Premium               2
#
#           days_per_week  attend_group_lesson            fav_group_lesson  \
# 0    Mon, Sat, Tue, Wed                 True  Kickboxen, BodyPump, Zumba
# ...

# %%
df=gym.copy()
df
# Out:
#        id  gender    birthday  Age abonoment_type  visit_per_week  \
# 0       1  Female  1997-04-18   27        Premium               4
# 1       2  Female  1977-09-18   47       Standard               3
# 2       3    Male  1983-03-30   41        Premium               1
# 3       4    Male  1980-04-12   44        Premium               3
# 4       5    Male  1980-09-10   44       Standard               2
# ..    ...     ...         ...  ...            ...             ...
# 995   996  Female  1984-09-22   40       Standard               3
# 996   997  Female  2008-11-19   15       Standard               3
# 997   998    Male  1984-10-05   40       Standard               2
# 998   999    Male  2001-02-22   23       Standard               4
# 999  1000  Female  2006-05-07   18        Premium               2
#
#           days_per_week  attend_group_lesson            fav_group_lesson  \
# 0    Mon, Sat, Tue, Wed                 True  Kickboxen, BodyPump, Zumba
# ...

# %%
df.head(3)
# Out:
#    id  gender    birthday  Age abonoment_type  visit_per_week  \
# 0   1  Female  1997-04-18   27        Premium               4
# 1   2  Female  1977-09-18   47       Standard               3
# 2   3    Male  1983-03-30   41        Premium               1
#
#         days_per_week  attend_group_lesson            fav_group_lesson  \
# 0  Mon, Sat, Tue, Wed                 True  Kickboxen, BodyPump, Zumba
# 1       Mon, Sat, Wed                False                         NaN
# 2                 Sat                 True                       XCore
#
#   avg_time_check_in avg_time_check_out  avg_time_in_gym  drink_abo  \
# 0          19:31:00           21:27:00              116      False
# 1          19:31:00           20:19:00               48      False
# 2          08:29:00           10:32:00              123       True
#
#             fav_drink  personal_training name_personal_trainer  uses_sauna
# 0                 NaN              False                   NaN        True
# ...

# %%
df.tail(3)
# Out:
#        id  gender    birthday  Age abonoment_type  visit_per_week  \
# 997   998    Male  1984-10-05   40       Standard               2
# 998   999    Male  2001-02-22   23       Standard               4
# 999  1000  Female  2006-05-07   18        Premium               2
#
#           days_per_week  attend_group_lesson fav_group_lesson  \
# 997            Fri, Tue                False              NaN
# 998  Mon, Sun, Thu, Tue                 True       HIT, XCore
# 999            Thu, Tue                False              NaN
#
#     avg_time_check_in avg_time_check_out  avg_time_in_gym  drink_abo  \
# 997          17:21:00           19:53:00              152       True
# 998          10:23:00           12:29:00              126       True
# 999          16:41:00           19:00:00              139       True
#
#                             fav_drink  personal_training  \
# 997  coconut_pineapple, black_currant               True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1000 non-null   int64
#  1   gender                 1000 non-null   object
#  2   birthday               1000 non-null   object
#  3   Age                    1000 non-null   int64
#  4   abonoment_type         1000 non-null   object
#  5   visit_per_week         1000 non-null   int64
#  6   days_per_week          1000 non-null   object
#  7   attend_group_lesson    1000 non-null   bool
#  8   fav_group_lesson       503 non-null    object
#  9   avg_time_check_in      1000 non-null   object
#  10  avg_time_check_out     1000 non-null   object
#  11  avg_time_in_gym        1000 non-null   int64
#  12  drink_abo              1000 non-null   bool
#  13  fav_drink              496 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# id                         0
# gender                     0
# birthday                   0
# Age                        0
# abonoment_type             0
# visit_per_week             0
# days_per_week              0
# attend_group_lesson        0
# fav_group_lesson         497
# avg_time_check_in          0
# avg_time_check_out         0
# avg_time_in_gym            0
# drink_abo                  0
# fav_drink                504
# personal_training          0
# name_personal_trainer    482
# uses_sauna                 0
# dtype: int64

# %%
# Fill missing values for numerical columns with the mode
df['fav_group_lesson'] = df['fav_group_lesson'].fillna(df['fav_group_lesson'].mode()[0])
df['fav_group_lesson']
# Out:
# 0      Kickboxen, BodyPump, Zumba
# 1                        BodyPump
# 2                           XCore
# 3                        BodyPump
# 4            Running, Yoga, Zumba
#                   ...
# 995                      BodyPump
# 996                  XCore, Zumba
# 997                      BodyPump
# 998                    HIT, XCore
# 999                      BodyPump
# Name: fav_group_lesson, Length: 1000, dtype: object

# %%
df['fav_drink'] = df['fav_drink'].fillna(df['fav_drink'].mode()[0])
df['fav_drink']
# Out:
# 0                     coconut_pineapple
# 1                     coconut_pineapple
# 2                    berry_boost, lemon
# 3                         passion_fruit
# 4                     coconut_pineapple
#                      ...
# 995                   coconut_pineapple
# 996                       orange, lemon
# 997    coconut_pineapple, black_currant
# 998                         berry_boost
# 999    passion_fruit, coconut_pineapple
# Name: fav_drink, Length: 1000, dtype: object

# %%
df['name_personal_trainer'] = df['name_personal_trainer'].fillna('No Trainer')
df['name_personal_trainer']
# Out:
# 0      No Trainer
# 1         Chantal
# 2            Mike
# 3            Mike
# 4            Mike
#           ...
# 995    No Trainer
# 996    No Trainer
# 997       Jeffrey
# 998       Jeffrey
# 999    No Trainer
# Name: name_personal_trainer, Length: 1000, dtype: object

# %%
df.isnull().sum()
# Out:
# id                       0
# gender                   0
# birthday                 0
# Age                      0
# abonoment_type           0
# visit_per_week           0
# days_per_week            0
# attend_group_lesson      0
# fav_group_lesson         0
# avg_time_check_in        0
# avg_time_check_out       0
# avg_time_in_gym          0
# drink_abo                0
# fav_drink                0
# personal_training        0
# name_personal_trainer    0
# uses_sauna               0
# dtype: int64

# %%
df
# Out:
#        id  gender    birthday  Age abonoment_type  visit_per_week  \
# 0       1  Female  1997-04-18   27        Premium               4
# 1       2  Female  1977-09-18   47       Standard               3
# 2       3    Male  1983-03-30   41        Premium               1
# 3       4    Male  1980-04-12   44        Premium               3
# 4       5    Male  1980-09-10   44       Standard               2
# ..    ...     ...         ...  ...            ...             ...
# 995   996  Female  1984-09-22   40       Standard               3
# 996   997  Female  2008-11-19   15       Standard               3
# 997   998    Male  1984-10-05   40       Standard               2
# 998   999    Male  2001-02-22   23       Standard               4
# 999  1000  Female  2006-05-07   18        Premium               2
#
#           days_per_week  attend_group_lesson            fav_group_lesson  \
# 0    Mon, Sat, Tue, Wed                 True  Kickboxen, BodyPump, Zumba
# ...

# %%
df.describe()
# Out:
#                 id          Age  visit_per_week  avg_time_in_gym
# count  1000.000000  1000.000000     1000.000000      1000.000000
# mean    500.500000    30.604000        2.682000       105.260000
# std     288.819436    10.817958        1.241941        43.557177
# min       1.000000    12.000000        1.000000        30.000000
# 25%     250.750000    21.000000        2.000000        67.000000
# 50%     500.500000    30.000000        3.000000       104.000000
# 75%     750.250000    40.000000        3.000000       143.000000
# max    1000.000000    49.000000        5.000000       180.000000

# %%
df=df.rename(columns={'abonoment_type':'subscribed'})
df
# Out:
#        id  gender    birthday  Age subscribed  visit_per_week  \
# 0       1  Female  1997-04-18   27    Premium               4
# 1       2  Female  1977-09-18   47   Standard               3
# 2       3    Male  1983-03-30   41    Premium               1
# 3       4    Male  1980-04-12   44    Premium               3
# 4       5    Male  1980-09-10   44   Standard               2
# ..    ...     ...         ...  ...        ...             ...
# 995   996  Female  1984-09-22   40   Standard               3
# 996   997  Female  2008-11-19   15   Standard               3
# 997   998    Male  1984-10-05   40   Standard               2
# 998   999    Male  2001-02-22   23   Standard               4
# 999  1000  Female  2006-05-07   18    Premium               2
#
#           days_per_week  attend_group_lesson            fav_group_lesson  \
# 0    Mon, Sat, Tue, Wed                 True  Kickboxen, BodyPump, Zumba
# ...

# %% [markdown]
# Histogram

# %%
import matplotlib.pyplot as plt

# Example: Age distribution
df['Age'].hist()
plt.hist(df['Age'],color='#9BA2FF',edgecolor='#0F0F0F')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [raw]
# Bar Plot

# %%
# Example: Gender distribution

df['gender'].value_counts().plot(kind='bar')
plt.hist(df['Age'],color='orange',edgecolor='#227B94')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Box Plot

# %%
import seaborn as sns

# Example: Age distribution
sns.boxplot(x=df['Age'])
plt.title('Age Box Plot')
plt.xlabel('Age')
plt.show()

# %% [raw]
# Scatter Plot

# %%
# Example: Relationship between age and visit_per_week
plt.scatter(df['Age'], df['visit_per_week'])
plt.title('Age vs Visit per Week')
plt.xlabel('Age')
plt.ylabel('Visit per Week')
plt.show()

# %% [markdown]
# KDE - Kernel Density Estimate

# %%
# Example: KDE plot for Age
import warnings
warnings.filterwarnings('ignore')
sns.kdeplot(df['Age'], shade=True)
plt.title('Age KDE Plot')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()

# %%
hm=40

# %%
t_stat,p_value=ttest_1samp(df['Age'],hm)
alpha=0.05

print(f"t-statistic:{t_stat}")
print(f"p-value:{p_value}")

if p_value < alpha:
    print(f"Reject the null hypothesis at alpha = {alpha}")
else:
    print(f"fail to reject the null hypothesis at alpha={alpha}")
# Out:
# t-statistic:-27.466145908153884
# p-value:3.551059385295412e-124
# Reject the null hypothesis at alpha = 0.05
